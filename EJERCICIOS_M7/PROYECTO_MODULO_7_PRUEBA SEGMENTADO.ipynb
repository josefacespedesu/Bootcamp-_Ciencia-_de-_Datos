# %% [markdown]
# # Proyecto: Segmentador Inteligente de Clientes Minoristas

# %% [markdown]
# <b><font color= "red">Lección 1: Fundamentos del Aprendizaje No Supervisado</b></font>
# <b> Comprender los fundamentos teóricos del aprendizaje no supervisado y sus diferencias con el aprendizaje supervisado. </b>

# %% [markdown]
# **● ¿Qué es el aprendizaje no supervisado?**

# %% [markdown]
# El aprendizaje de máquina no supervisado es una rama del machine learning que se utiliza para analizar datos que no poseen etiquetas o variables objetivo predefinidas. A diferencia del aprendizaje supervisado, donde el modelo aprende a partir de ejemplos con respuestas conocidas, en el aprendizaje no supervisado los algoritmos buscan descubrir patrones, estructuras o relaciones ocultas dentro de los datos sin una guía explícita.
#
# El objetivo principal de este enfoque es comprender la estructura subyacente del conjunto de datos, identificando similitudes, agrupaciones o comportamientos recurrentes que no son evidentes a simple vista. Por esta razón, el aprendizaje no supervisado se utiliza con frecuencia en análisis exploratorio de datos, donde se busca obtener una primera comprensión de la información disponible antes de construir modelos predictivos.
#
# Una de sus principales ventajas es que permite trabajar con grandes volúmenes de datos no etiquetados, los cuales son muy comunes en entornos reales como registros de clientes, interacciones en plataformas digitales, imágenes, texto o datos de sensores. Además, facilita la identificación de relaciones complejas o patrones ocultos, que pueden ser utilizados posteriormente para la toma de decisiones estratégicas o para mejorar modelos de análisis más avanzados.
#
# No obstante, este tipo de aprendizaje también presenta ciertos desafíos. Debido a que no existe una respuesta correcta conocida, evaluar la calidad de los resultados puede ser más complejo, y la interpretación de los patrones encontrados requiere conocimiento del dominio del problema. Asimismo, la selección del algoritmo y de sus parámetros puede influir significativamente en los resultados obtenidos.
#
# A pesar de estas limitaciones, el aprendizaje no supervisado constituye una herramienta fundamental dentro de la ciencia de datos moderna, especialmente cuando el objetivo es explorar, comprender y estructurar grandes conjuntos de datos antes de aplicar modelos más complejos.

# %% [markdown]
# **● Identiﬁcar las principales tareas que resuelve el aprendizaje no supervisado**

# %% [markdown]
# El aprendizaje no supervisado se utiliza para resolver diferentes tipos de problemas relacionados con la identificación de patrones en datos sin etiquetas. Entre las tareas más relevantes se encuentran la clusterización, la reducción de dimensionalidad, la detección de anomalías y el análisis de reglas de asociación.
#
# <u>1. Clusterización (Clustering)</u>
#
# La clusterización consiste en agrupar observaciones de manera que los elementos dentro de un mismo grupo sean más similares entre sí que con los de otros grupos. Este proceso permite identificar segmentos o estructuras naturales dentro de los datos sin necesidad de conocer previamente cuáles son esos grupos.
# Esta técnica es ampliamente utilizada en diversos contextos, como por ejemplo:
#
# - Segmentación de clientes según comportamiento de compra
# - Agrupamiento de productos con características similares
# - Análisis de comportamiento de usuarios en plataformas digitales
# - Organización automática de imágenes o documentos
#
# <u> 2. Reducción de dimensionalidad</u>
#
# La reducción de dimensionalidad busca disminuir la cantidad de variables o características presentes en un conjunto de datos, manteniendo la mayor cantidad posible de información relevante.
# En muchos problemas reales, los datasets pueden contener decenas o cientos de variables, lo que dificulta su análisis y visualización. Mediante técnicas de reducción dimensional es posible simplificar la representación de los datos, facilitando tanto su interpretación como el procesamiento computacional.
# Entre sus principales aplicaciones se encuentran:
# - Visualización de datos complejos en dos o tres dimensiones
# - Eliminación de redundancias entre variables
# - Mejora del rendimiento (y eficiencia computacional) de algoritmos de machine learning
# - Preparación de datos para otras tareas como clusterización
#
# <u> 3. Detección de anomalías</u>
#
# La detección de anomalías tiene como objetivo identificar observaciones que se comportan de forma significativamente diferente al resto de los datos. Estas observaciones atípicas pueden representar eventos inusuales o potencialmente problemáticos.
# Este tipo de análisis es particularmente importante en contextos donde detectar comportamientos fuera de lo normal puede generar un gran valor, por ejemplo:
# - Identificación de fraudes financieros
# - Detección de fallos en sistemas o sensores industriales
# - Identificación de transacciones sospechosas en comercio electrónico
# - Monitoreo de seguridad en redes informáticas
# - Identificación de comportamientos atípicos de usuarios
#
#
# <u> 4. Análisis de reglas de asociación</u>
#
# El análisis de reglas de asociación busca descubrir relaciones frecuentes entre diferentes variables dentro de un conjunto de datos. En otras palabras, identifica qué eventos o elementos tienden a ocurrir juntos. A diferencia de la clusterización, que agrupa observaciones, estas técnicas se enfocan en descubrir patrones de co-ocurrencia entre elementos.
# Este tipo de análisis es particularmente conocido en el ámbito del retail y el comercio electrónico, donde se utiliza para estudiar el comportamiento de compra de los clientes. Un ejemplo clásico corresponde al análisis de canasta de mercado, que identifica patrones como:
#
# Los clientes que compran un determinado producto tienden a comprar también otro producto relacionado. Un ejemplo sería:
#
# “Los clientes que compran pan también suelen comprar mantequilla”.
#
# Este tipo de información permite a las empresas:
# - Diseñar estrategias de ventas cruzadas (cross-selling)
# - Optimizar la disposición de productos en tiendas
# - Crear recomendaciones personalizadas en plataformas de e-commerce

# %% [markdown]
# Es importante destacar que estas tareas no son excluyentes y en muchos proyectos de ciencia de datos se utilizan de manera combinada. Por ejemplo, es común aplicar reducción de dimensionalidad antes de realizar una clusterización, con el objetivo de simplificar los datos y mejorar la calidad de los grupos obtenidos.
#
# La selección de la técnica más adecuada dependerá del tipo de problema, los objetivos del análisis y las características del conjunto de datos. Una elección adecuada permite obtener resultados que no solo sean técnicamente correctos, sino también interpretables y útiles para la toma de decisiones.

# %% [markdown]
# **● Clasiﬁcar técnicas por tipo (clusterización, reducción, asociación)**

# %% [markdown]
# <u> 1. Técnicas de clusterización</u>
#
# Entre los algoritmos más conocidos dentro de esta categoría se encuentran:
#
# - K-Means, que agrupa los datos alrededor de centroides representativos de cada grupo.
#
# - DBSCAN, que identifica clústeres basándose en la densidad de los puntos en el espacio de datos.
#
# - Agrupamiento jerárquico, que construye una estructura en forma de árbol que muestra cómo se relacionan los diferentes grupos entre sí.
#
# <u> 2. Técnicas de reducción de dimensionalidad</u>
#
# Entre los métodos más utilizados se encuentran:
#
# - PCA (Análisis de Componentes Principales), que transforma las variables originales en nuevas componentes que capturan la mayor varianza posible de los datos.
#
# - t-SNE (t-Distributed Stochastic Neighbor Embedding), que es especialmente útil para visualizar estructuras complejas en espacios de baja dimensión.
#
# Estas técnicas son muy utilizadas en análisis exploratorio de datos, ya que permiten identificar patrones y estructuras que serían difíciles de observar en espacios de alta dimensionalidad.
#
# <u> 3. Técnicas de análisis de asociaciones </u>
#
# Entre los algoritmos más utilizados en esta categoría se encuentran:
#
# - Apriori
#
# - FP-Growth
#
# <u> 4. Técnicas de detección de anomalías</u>
#
# Existen distintos enfoques para detectar anomalías en los datos. Entre los más utilizados se encuentran los siguientes:
#
# **a) Métodos estadísticos**
#
# Los métodos estadísticos se basan en el supuesto de que los datos siguen una determinada distribución probabilística. A partir de esta distribución, se identifican como anomalías aquellos valores que se encuentran muy alejados de la media o del comportamiento esperado. Estos métodos suelen utilizar medidas de dispersión y probabilidad para determinar qué observaciones pueden considerarse atípicas.
#
# Entre las técnicas más utilizadas se encuentran:
#
# - Z-score, que mide cuántas desviaciones estándar se encuentra un valor respecto de la media.
# - Test de Grubbs, utilizado para detectar outliers en muestras que siguen una distribución normal.
#
# Estos métodos son especialmente útiles cuando se trabaja con datasets relativamente simples y distribuciones bien definidas.
#
# **b) Métodos basados en distancia**
#
# Los métodos basados en distancia identifican anomalías evaluando qué tan lejos se encuentra una observación respecto de sus vecinos más cercanos dentro del espacio de características. La idea central es que los puntos anómalos tienden a estar aislados o más alejados de otras observaciones, mientras que los datos normales suelen formar regiones más compactas.
#
# Entre los algoritmos más conocidos se encuentran:
#
# - k-Nearest Neighbors (k-NN) aplicado a detección de outliers
# - Local Outlier Factor (LOF), que compara la densidad local de un punto con la de sus vecinos
#
# Estos métodos son útiles cuando los datos presentan estructuras complejas que no siguen distribuciones estadísticas simples.
#
# **C) Métodos basados en densidad**
#
# Los métodos basados en densidad detectan anomalías analizando la concentración de datos en diferentes regiones del espacio. Las observaciones que se encuentran en áreas donde la densidad de puntos es muy baja suelen considerarse anomalías. Estos enfoques son particularmente útiles cuando los datos presentan agrupaciones naturales o clústeres, ya que permiten identificar puntos que no pertenecen claramente a ningún grupo.
#
# Un algoritmo representativo es:
#
# - DBSCAN adaptado, que identifica automáticamente puntos de ruido (noise) cuando estos no cumplen con los criterios mínimos de densidad para formar parte de un clúster.
#
# Este tipo de método es muy útil en datasets con estructuras irregulares o clusters de forma no lineal.
#
# **d) Métodos basados en modelos**
#
# Los métodos basados en modelos construyen primero un modelo que representa el comportamiento normal de los datos. Posteriormente, aquellas observaciones que presentan una desviación significativa respecto a ese comportamiento esperado son consideradas anomalías. Este enfoque es especialmente útil en problemas donde el patrón normal es relativamente estable y las anomalías representan desviaciones claras.
#
# Entre los algoritmos más utilizados se encuentran:
#
# - One-Class SVM, que aprende una frontera que encapsula las observaciones normales.
# - Autoencoders, redes neuronales que aprenden representaciones comprimidas de los datos y detectan anomalías cuando la reconstrucción presenta errores elevados.
# - Isolation Forest, que identifica anomalías aislando observaciones mediante particiones aleatorias del espacio de datos.
#
# Estos métodos son particularmente efectivos en datasets complejos o de alta dimensionalidad, donde los enfoques tradicionales pueden ser menos eficientes.

# %% [markdown]
# **Tabla resumen**

# %% [markdown]
# | Tipo de técnica                  | Objetivo principal                                                                                                   | Ejemplos de algoritmos                   | Aplicaciones comunes                                                                                         |
# | -------------------------------- | -------------------------------------------------------------------------------------------------------------------- | ---------------------------------------- | ------------------------------------------------------------------------------------------------------------ |
# | **Clusterización**               | Agrupar observaciones similares para identificar estructuras o segmentos dentro de los datos.                        | K-Means, DBSCAN, Agrupamiento Jerárquico | Segmentación de clientes, agrupamiento de documentos o imágenes, análisis de comportamiento de usuarios.     |
# | **Reducción de dimensionalidad** | Reducir el número de variables manteniendo la mayor información posible, facilitando el análisis y la visualización. | PCA, t-SNE, UMAP                         | Visualización de datos complejos, preprocesamiento para modelos, eliminación de redundancia entre variables. |
# | **Análisis de asociaciones**     | Identificar relaciones o patrones de co-ocurrencia entre variables dentro de los datos.                              | Apriori, FP-Growth                       | Análisis de canasta de mercado, sistemas de recomendación, ventas cruzadas.                                  |
# | **Detección de anomalías**       | Identificar observaciones atípicas que se desvían significativamente del comportamiento general de los datos.        | LOF, Isolation Forest, One-Class SVM, Autoencoders     | Detección de fraude, monitoreo de sistemas, identificación de comportamientos inusuales.                     |

# %% [markdown]
# | **Tipo de técnica**             | **Ejemplos de algoritmos**                                                |
# | -------------------------------- | ------------------------------------------------------------------------- |
# | Clusterización                   | K-Means, DBSCAN, Agrupamiento Jerárquico, Gaussian Mixture Models         |
# | Reducción de dimensionalidad     | PCA, t-SNE, UMAP                                                          |
# | Análisis de asociaciones         | Apriori, FP-Growth, Eclat                                                 |
# | Detección de anomalías           | Local Outlier Factor (LOF), Isolation Forest, One-Class SVM, Autoencoders |

# %% [markdown]
# **Analizar casos reales de aplicación**

# %% [markdown]
# <u> Segmentación de clientes en retail y marketing</u>
#
# Una de las aplicaciones más comunes del aprendizaje no supervisado es la segmentación de clientes, donde las empresas buscan identificar grupos de consumidores con comportamientos o características similares. A través de técnicas de clusterización, es posible agrupar clientes según variables como frecuencia de compra, gasto promedio, preferencias de productos o canales de compra.
#
# Esta segmentación permite a las empresas diseñar estrategias de marketing más personalizadas, mejorar campañas de fidelización y optimizar la asignación de recursos comerciales. Por ejemplo, un retailer puede identificar segmentos como clientes frecuentes de alto valor, compradores ocasionales o clientes sensibles a promociones, y desarrollar estrategias específicas para cada grupo.
#
# <u> Sistemas de recomendación en plataformas digitales</u>
#
# Las plataformas de comercio electrónico y servicios digitales utilizan técnicas de aprendizaje no supervisado para analizar patrones de consumo y comportamiento de los usuarios, lo que permite generar recomendaciones personalizadas. A partir de la identificación de similitudes entre productos o usuarios, los sistemas pueden sugerir artículos que podrían resultar de interés para un cliente determinado.
#
# Este enfoque es ampliamente utilizado en plataformas de e-commerce, servicios de streaming y redes sociales, donde la recomendación automática de contenido contribuye a mejorar la experiencia del usuario y aumentar la probabilidad de compra o interacción.
#
# <u> Detección de fraudes en sistemas financieros</u>
#
# Otra aplicación importante del aprendizaje no supervisado es la detección de anomalías en transacciones financieras. Mediante el análisis de patrones normales de comportamiento, los algoritmos pueden identificar transacciones que se desvían significativamente del comportamiento habitual de un usuario o de un grupo de usuarios.
#
# Este tipo de análisis permite detectar posibles fraudes, actividades sospechosas o errores en los sistemas de registro, lo que contribuye a mejorar la seguridad y reducir riesgos financieros.
#
# <u> Análisis de datos en salud</u>
#
# En el ámbito de la salud, el aprendizaje no supervisado se utiliza para identificar patrones en grandes conjuntos de datos clínicos, como registros médicos, resultados de laboratorio o información genética. Las técnicas de clusterización permiten agrupar pacientes con características similares, lo que puede ayudar a identificar subgrupos dentro de una enfermedad o mejorar la comprensión de ciertos procesos clínicos.
#
# Este tipo de análisis es especialmente útil en investigación médica, donde se busca descubrir relaciones complejas entre variables biológicas o clínicas que podrían no ser evidentes mediante métodos tradicionales.
#
# <u> Aplicación en el proyecto de segmentación de clientes</u>
#
# En el contexto del presente proyecto, el aprendizaje no supervisado se utiliza para analizar el comportamiento de los clientes de una empresa minorista, con el objetivo de identificar segmentos de consumidores con patrones de compra similares. A partir de técnicas de reducción de dimensionalidad y clusterización, es posible visualizar la estructura de los datos y descubrir grupos de clientes que puedan ser utilizados para mejorar estrategias de marketing, fidelización y ventas cruzadas.
#
# Este tipo de enfoque permite transformar grandes volúmenes de datos en información accionable para la toma de decisiones empresariales, facilitando una comprensión más profunda del comportamiento del cliente.

# %% [markdown]
# <b><font color= "red">Lección 2: Técnicas de Clusterización</b></font>
# <b> Conocer en profundidad la técnica de clusterización y sus aplicaciones</b>

# %% [markdown]
# **Deﬁnir escenarios donde se aplique clusterización**

# %% [markdown]
# En el ámbito empresarial, esta técnica resulta especialmente útil para analizar comportamientos heterogéneos dentro de grandes volúmenes de datos, permitiendo identificar patrones que facilitan la toma de decisiones estratégicas.
#
# Algunos escenarios de aplicación incluyen:
#
# - Segmentación de clientes, identificando perfiles de consumo o comportamiento de compra
# - Análisis de comportamiento de usuarios en plataformas digitales, agrupando patrones de navegación o interacción
# - Agrupamiento de productos, detectando similitudes entre artículos según ventas o características
# - Organización de Documentos, clasificando documentos por temas o contenido similar sin etiquetas previas
# - Agrupación de imágenes, organizando imágenes por características visuales similares
# -  Análisis Genómico, identificando patrones en datos genéticos para investigación médica
# - Análisis exploratorio de datos, para comprender la estructura interna de datasets complejos
# - Detección de fallos en sistemas industriales
# - Análisis de tráﬁco en redes o sistemas
# - Agrupamiento de regiones geográﬁcas por clima o características socioeconómicas

# %% [markdown]
# **Explicar ventajas y desventajas de la técnica**

# %% [markdown]
# Entre sus principales <u>ventajas</u> destacan:
#
# - Permite descubrir patrones ocultos en los datos (Mediante la agrupación de datos similares, se pueden obtener valiosos conocimientos ocultos que son útiles en diversos campos)
#
# - Facilita la segmentación de poblaciones heterogéneas
#
# - Permite no solo entender mejor los datos, sino también tomar decisiones basadas en comportamientos, tendencias o
# características compartidas entre subconjuntos.
#
# - Contribuye al análisis exploratorio de grandes datasets
#
# - Puede utilizarse como etapa previa a otros modelos de machine learning
#
# Sin embargo, también presenta ciertas limitaciones o <u>desventajas</u> que deben considerarse durante su aplicación:
#
# - Necesidad de normalizar los datos para evitar que variables con escalas mayores dominen el análisis.
#
# - Sensibilidad al método de distancia elegido, que puede afectar signiﬁcativamente los resultados.
#
#
# - Algunos algoritmos son sensibles a outliers o a la escala de las variables.
#
# - La elección de parámetros y número de clústeres puede influir significativamente en los resultados.
#
# - Validar los resultados sin etiquetas puede ser complejo y requiere métodos adicionales como el índice de Silhouette
#
# - La interpretación de los clústeres puede requerir conocimiento del dominio del problema.
#
# Por esta razón, es habitual complementar la clusterización con métricas de evaluación y visualización de datos para validar la calidad de los grupos obtenidos.

# %% [markdown]
# **Comparar K-Means, DBSCAN y agrupamiento jerárquico teóricamente**

# %% [markdown]
# | Algoritmo                   | Principio de funcionamiento                                                                                          | Características principales                                                                                                              |
# | --------------------------- | -------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------- |
# | **K-Means**                 | Agrupa los datos alrededor de centroides que representan el centro de cada clúster.                                  | Es rápido y eﬁciente para grandes volúmenes de datos, pero requiere deﬁnir el número de clústeres previamente. Es sensible a valores atípicos.            |
# | **DBSCAN**                  | Identifica clústeres como regiones de alta densidad separadas por regiones de baja densidad.                         | Permite detectar clústeres de forma arbitraria y reconocer ruido en los datos, sin necesidad de definir previamente el número de grupos. Su rendimiento puede deteriorarse con variaciones de densidad. |
# | **Agrupamiento jerárquico** | Construye una estructura de agrupamiento en forma de árbol (dendrograma) basada en la distancia entre observaciones. | Permite explorar diferentes niveles de agrupamiento, no requiere deﬁnir K inicialmente. Produce un dendrograma útil para análisis visual, pero su complejidad computacional lo hace ineﬁciente en datasets muy grandes.           |

# %% [markdown]
# **Asociar cada algoritmo a un tipo de dato o problema real**

# %% [markdown]
# | Algoritmo                   | Ejemplo de aplicación en una situación real                                                                                                                                                                                                                                                                                                                                                                                             |
# | --------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **K-Means**                 | Una empresa de retail analiza el historial de compras de miles de clientes considerando variables como frecuencia de compra, gasto promedio y variedad de productos adquiridos. Mediante K-Means se identifican distintos segmentos de clientes, como compradores frecuentes de alto valor, clientes ocasionales y consumidores sensibles a promociones, permitiendo diseñar campañas de marketing diferenciadas para cada grupo.       |
# | **DBSCAN**                  | Una plataforma de comercio electrónico analiza el comportamiento de compra de sus usuarios para identificar patrones habituales. Al aplicar DBSCAN, el algoritmo agrupa a la mayoría de los clientes con comportamientos similares, mientras que identifica como ruido ciertas transacciones atípicas, como compras extremadamente grandes o patrones de compra inusuales que podrían indicar fraude o errores en el registro de datos. |
# | **Agrupamiento jerárquico** | Un equipo de análisis de mercado estudia las preferencias de consumidores respecto a diferentes categorías de productos. Utilizando agrupamiento jerárquico, se construye un dendrograma que permite observar cómo se relacionan distintos grupos de consumidores, identificando subsegmentos dentro de segmentos más amplios, lo que facilita comprender la estructura del mercado y diseñar estrategias comerciales más específicas.  |

# %% [markdown]
# <b><font color= "red">Lección 3: Reducción Dimensional y Preprocesamiento</b></font>
# <b> Objetivo: Aprender a aplicar técnicas de reducción de dimensionalidad como PCA y t-SNE. </b>

# %% [markdown]
# **Preparar un dataset de alta dimensión**

# %% [markdown]
# El dataset que se utiliza para la elaboración de este proyecto es "Customer Segmentation Classification" de la plataforma Kaggle. El dataset seleccionado resulta adecuado para la aplicación de técnicas de aprendizaje no supervisado, ya que contiene variables relevantes para el análisis de comportamiento de clientes y no presenta una variable objetivo definida. Esto permite aplicar métodos de reducción dimensional y algoritmos de clusterización para identificar segmentos de clientes, facilitando la generación de insights útiles para la toma de decisiones en el ámbito del retail.

# %% [markdown]
# **Variables del dataset**

# %% [markdown]
# | Variable            | Tipo                       | Descripción                                                                                 |
# | ------------------- | -------------------------- | ------------------------------------------------------------------------------------------- |
# | ID                  | Categórica (identificador) | Identificador único de cada cliente. No aporta valor analítico.                             |
# | Gender              | Categórica                 | Género del cliente.                                                                         |
# | Ever_Married        | Categórica                 | Indica si el cliente ha estado casado alguna vez.                                           |
# | Age                 | Numérica                   | Edad del cliente.                                                                           |
# | Graduated           | Categórica                 | Indica si el cliente es graduado.                                                           |
# | Profession          | Categórica                 | Profesión del cliente.                                                                      |
# | Work_Experience     | Numérica                   | Años de experiencia laboral.                                                                |
# | Spending_Score      | Categórica (ordinal)       | Nivel de gasto del cliente (ej: Low, Average, High).                                        |
# | Family_Size         | Numérica                   | Número de miembros en la familia del cliente.                                               |
# | Var_1               | Categórica                 | Variable categórica adicional sin descripción específica en el dataset.                     |
# | Segmentation        | Categórica (objetivo)      | Segmento asignado al cliente (A, B, C, D). **No se utiliza en aprendizaje no supervisado.** |

# %%
import pandas as pd

df = pd.read_csv("Train.csv")

# %% [markdown]
# Primera visualización del dataset

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %% [markdown]
# Eliminamos columna que no se usarán, ID y Segmentation (A, B, C, D) que es una etiqueta y no se usará porque el proyecto está enfocado en aprendizaje no supervisado.

# %%
df = df.drop(columns=["ID"])

# %% [markdown]
# Exploro el dataset

# %%
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           8068 non-null   str
#  1   Ever_Married     7928 non-null   str
#  2   Age              8068 non-null   int64
#  3   Graduated        7990 non-null   str
#  4   Profession       7944 non-null   str
#  5   Work_Experience  7239 non-null   float64
#  6   Spending_Score   8068 non-null   str
#  7   Family_Size      7733 non-null   float64
#  8   Var_1            7992 non-null   str
#  9   Segmentation     8068 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 630.4 KB

# %%
df.isnull().sum()
# Out:
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %% [markdown]
# Dado que el dataset presenta una cantidad significativa de valores faltantes en algunas variables, especialmente en Work_Experience y Family_Size, no se optó por eliminar las observaciones incompletas, ya que esto habría implicado una pérdida considerable de información y una posible introducción de sesgo en el análisis.
#
# En su lugar, se aplicaron técnicas de imputación: se utilizó la mediana para variables numéricas, debido a su robustez frente a valores atípicos, y moda  y creación de una nueva variable "Unknown" (en el caso de profession) para variables categóricas, preservando así la distribución original de los datos.
#
# Esta decisión se basa en que, la imputación de valores faltantes es especialmente relevante en técnicas de clusterización, ya que la eliminación de datos puede distorsionar la formación de los clústeres y afectar la representatividad de los segmentos identificados.

# %% [markdown]
# **Imputación variables numéricas**: Se imputa por la mediana ya que, es mejor que la media porque es robusta ante outliers.

# %%
from sklearn.impute import SimpleImputer

num_cols = ['Work_Experience', 'Family_Size']

imputer_num = SimpleImputer(strategy='median')
df[num_cols] = imputer_num.fit_transform(df[num_cols])

# %% [markdown]
# **Imputación variables categóricas**: Para el tratamiento de valores faltantes en variables categóricas se utilizó un enfoque mixto. En la variable "Profession", se optó por crear una categoría adicional denominada “Unknown”, dado que la ausencia de información puede representar un segmento específico de clientes con características propias.
#
# En cambio, para variables más estructuradas como "Ever_Married" y "Graduated", se aplicó imputación mediante la moda, ya que en estos casos el valor faltante no necesariamente representa una categoría diferenciada.
#
# Este enfoque permite equilibrar la preservación de información con la interpretabilidad de los resultados, evitando tanto la pérdida de datos como la introducción de sesgos artificiales en el proceso de segmentación.

# %%
df['Profession'] = df['Profession'].fillna('Unknown')

cat_cols = ['Ever_Married', 'Graduated', 'Var_1']
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %% [markdown]
# **Codificación de variables categóricas**
#
# Se codifican como variables Dummy.

# %%
df = pd.get_dummies(df, drop_first=True)

df.head()
# Out:
#    Age  Work_Experience  Family_Size  Gender_Male  Ever_Married_Yes  \
# 0   22              1.0          4.0         True             False
# 1   38              1.0          3.0        False              True
# 2   67              1.0          1.0        False              True
# 3   67              0.0          2.0         True              True
# 4   40              1.0          6.0        False              True
#
#    Graduated_Yes  Profession_Doctor  Profession_Engineer  \
# 0          False              False                False
# 1           True              False                 True
# 2           True              False                 True
# 3           True              False                False
# 4           True              False                False
#
#    Profession_Entertainment  Profession_Executive  ...  Spending_Score_Low  \
# 0                     False                 False  ...                True
# ...

# %% [markdown]
# **Implementar PCA y t-SNE con scikit-learn**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# Aplico estandarización

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %% [markdown]
# <font size=6>**PCA**</font>

# %% [markdown]
# Primero se realiza un análisis de la varianza explicada y acumulada

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

var_exp = pca.explained_variance_ratio_
var_acum = np.cumsum(var_exp)

# Mostrar resultados
resultados = pd.DataFrame({
    "Componente": [f"PC{i}" for i in range(1, len(var_exp) + 1)],
    "Varianza_Explicada": var_exp,
    "Varianza_Acumulada": var_acum
})

print(resultados)
# Out:
#    Componente  Varianza_Explicada  Varianza_Acumulada
# 0         PC1            0.140731            0.140731
# 1         PC2            0.073402            0.214133
# 2         PC3            0.064424            0.278557
# 3         PC4            0.056618            0.335174
# 4         PC5            0.051597            0.386771
# 5         PC6            0.049218            0.435989
# 6         PC7            0.046980            0.482969
# 7         PC8            0.044449            0.527418
# 8         PC9            0.042906            0.570324
# 9        PC10            0.040967            0.611291
# 10       PC11            0.040086            0.651377
# 11       PC12            0.039433            0.690810
# 12       PC13            0.038725            0.729535
# 13       PC14            0.038040            0.767575
# 14       PC15            0.033934            0.801509
# 15       PC16            0.033111            0.834620
# ...

# %% [markdown]
# El bajo porcentaje de varianza explicada por las primeras componentes principales sugiere que la estructura del dataset es altamente multidimensional, por lo que una proyección en 2D no logra capturar adecuadamente la complejidad de los datos.

# %% [markdown]
# Aplico PCA para dos dimensiones, con el fin de realizar gráfica

# %%
pca_2 = PCA(n_components=2)
X_pca = pca_2.fit_transform(X_scaled)

# %%
pca_df = pd.DataFrame(X_pca, columns=["PC1", "PC2"])

# %%
plt.figure(figsize=(7,6))

sns.scatterplot(
    data=pca_df,
    x="PC1",
    y="PC2",
    color="#4C72B0",
    alpha=0.6,

)

plt.title("Proyección de Clientes en 2D usando PCA", fontsize=14, weight="bold")
plt.xlabel("Componente Principal 1", fontsize=12)
plt.ylabel("Componente Principal 2", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# La proyección de los datos mediante PCA en dos componentes principales, muestra una distribución relativamente dispersa, sin una separación clara entre grupos. Esto es consistente con el bajo porcentaje de varianza explicada (22%), lo que indica que gran parte de la información original del dataset no se logra representar en solo dos dimensiones.
#
# En consecuencia, la visualización no permite identificar clústeres bien definidos, lo que sugiere que la estructura de los datos es compleja y no lineal, requiriendo más dimensiones para ser representada adecuadamente.

# %% [markdown]
# **Realizo un análisis exploratorio de las dos componentes principales**

# %% [markdown]
# Se analizan las cargas de las componentes principales, observando que las dos primeras concentran variables relacionadas con características demográficas y de consumo. Aunque se calcularon múltiples componentes, solo las dos primeras fueron utilizadas para visualización, ya que permiten representar los datos en dos dimensiones.

# %%
loadings = pd.DataFrame(
    pca.components_,
    columns=df.columns,   # 👈 usamos df
    index=[f"PC{i+1}" for i in range(len(pca.components_))]
)

loadings.head(2)
# Out:
#           Age  Work_Experience  Family_Size  Gender_Male  Ever_Married_Yes  \
# PC1  0.408354        -0.072573    -0.126031     0.040519          0.399122
# PC2  0.026618         0.141140    -0.378571    -0.121008         -0.188164
#
#      Graduated_Yes  Profession_Doctor  Profession_Engineer  \
# PC1       0.209961          -0.049605            -0.029205
# PC2       0.276584           0.048805            -0.115195
#
#      Profession_Entertainment  Profession_Executive  ...  Spending_Score_Low  \
# PC1                 -0.000261              0.147947  ...           -0.360024
# PC2                  0.026141             -0.293896  ...            0.285703
#
#      Var_1_Cat_2  Var_1_Cat_3  Var_1_Cat_4  Var_1_Cat_5  Var_1_Cat_6  \
# PC1    -0.068283    -0.072498    -0.110952    -0.032654     0.180928
# PC2    -0.102662    -0.147389    -0.403096    -0.050588     0.482067
#
#      Var_1_Cat_7  Segmentation_B  Segmentation_C  Segmentation_D
# ...

# %% [markdown]
# En la proyección de los datos sobre las dos primeras componentes principales, el eje horizontal (PC1) representa principalmente un gradiente asociado a variables como edad, estado civil y nivel de gasto. En este sentido, los puntos ubicados hacia la derecha del gráfico corresponden a clientes de mayor edad, con mayor probabilidad de estar casados y con un mayor nivel de gasto, mientras que hacia la izquierda se concentran perfiles con menor nivel de consumo.
#
# Por otro lado, el eje vertical (PC2) refleja diferencias relacionadas con la estructura familiar y ciertos patrones de consumo. En este eje, los puntos ubicados en la parte superior tienden a asociarse con clientes de menor gasto y determinadas categorías específicas, mientras que en la parte inferior se observan perfiles con mayor gasto y familias de mayor tamaño.

# %% [markdown]
# ESO VER SI LO OCUPO DESPUES

# %% [markdown]
# Se aplicó PCA con un enfoque complementario: una reducción basada en varianza explicada (80%) para comprender la estructura intrínseca del dataset. Este último enfoque permitió evidenciar que los datos requieren múltiples dimensiones para ser representados adecuadamente, lo que justifica su uso en etapas posteriores de modelado.

# %%
#pca_var80 = PCA(n_components=0.80)  # conservar 80% varianza
#X_pca_80 = pca_var80.fit_transform(X_scaled)

# %%
#n_components = X_pca_80.shape[1]

#pca_df_2 = pd.DataFrame(
    #X_pca_80,
    #columns=[f"PC{i+1}" for i in range(n_components)]
#)

#pca_df_2.head()

# %% [markdown]
# <font size=6>**t-SNE**</font>

# %% [markdown]
# Con el objetivo de evaluar cómo influyen los diferentes parámetros en la aplicación de t-SNE y en la gráfica, se realizó una prueba con distintos parámetros con el fin de encontrar el conjunto que representara mejor los datos (como fue realizado en el análisis de caso 5 del módulo) en particular perplexity que controla el número aproximado de vecinos que cada punto considera al construir la representación en menor dimensión. Llegandose a la conclusión que los mejores parámetros en este caso son perplexity=50, learning_rate=200, max_iter=100 y random_state=41.

# %%
tsne = TSNE(n_components=2,
    perplexity=50,
    learning_rate=200,
    max_iter=1000,
    random_state=42)
tsne_results = tsne.fit_transform(X_scaled)

# %%
# Crear DataFrame
tsne_df = pd.DataFrame(tsne_results, columns=["Dim1", "Dim2"])

plt.figure(figsize=(7,6))

sns.scatterplot(
    data=tsne_df,
    x="Dim1",
    y="Dim2",
    color="#4C72B0",
    alpha=0.6,
    s=60
)

plt.title("Visualización de Clientes con t-SNE", fontsize=14, weight="bold")
plt.xlabel("Dimensión 1")
plt.ylabel("Dimensión 2")

plt.tight_layout()
plt.show()

# %% [markdown]
# La visualización obtenida mediante t-SNE presenta una estructura más compacta y con indicios de agrupamientos locales, donde algunos conjuntos de puntos parecen formar regiones diferenciadas (que comparten ciertas características). Esto se debe a que t-SNE prioriza la preservación de relaciones de vecindad entre observaciones, permitiendo identificar patrones que no son evidentes en métodos lineales como PCA.
#
# Sin embargo, a pesar de que t-SNE permite visualizar posibles agrupaciones, las distancias entre los grupos no deben interpretarse de forma literal, ya que la técnica prioriza la cercanía local y puede exagerar la separación entre ellos (Los puntos cercanos sí son parecidos, pero los puntos lejanos no necesariamente son muy distintos).

# %% [markdown]
# **Visualizar y comparar los resultados**

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))

axes[0].scatter(
    data=pca_df,
    x="PC1",
    y="PC2",
    color="#4C72B0",
    alpha=0.6
)
axes[0].set_title("PCA")

axes[1].scatter(
    data=tsne_df,
    x="Dim1",
    y="Dim2",
    color="#4C72B0",
    alpha=0.6
)
axes[1].set_title("t-SNE")
# Out:
# Text(0.5, 1.0, 't-SNE')

# %% [markdown]
# Al comparar ambas técnicas, se observa que PCA no logra evidenciar una estructura clara en los datos al proyectarlos en dos dimensiones, lo cual es coherente con la baja varianza explicada por sus primeras componentes. En contraste, t-SNE permite visualizar agrupamientos más definidos, facilitando la identificación de posibles segmentos de clientes.
#
# Esta diferencia radica en la naturaleza de los métodos: mientras PCA es una técnica lineal que busca maximizar la varianza global, t-SNE es un método no lineal que preserva relaciones locales, siendo más adecuado para visualizar estructuras complejas.
#
# No obstante, t-SNE tiene limitaciones en términos de interpretabilidad y estabilidad, por lo que su uso se recomienda principalmente con fines exploratorios.

# %% [markdown]
# **Justiﬁcar cuál técnica conviene para el problema actual**

# %% [markdown]
# Para el problema de segmentación de clientes, se concluye que ambas técnicas cumplen roles complementarios.
#
# Por un lado, PCA resulta más adecuado como técnica de preprocesamiento, ya que permite reducir la dimensionalidad del dataset manteniendo la mayor parte de la información relevante, lo que es especialmente útil para su aplicación en algoritmos de clusterización en etapas posteriores.
#
# Por otro lado, t-SNE es más efectivo para la visualización exploratoria, ya que facilita la identificación de posibles agrupamientos en los datos, incluso cuando la estructura es no lineal.
#
# En este contexto, se opta por utilizar PCA como técnica principal para la reducción dimensional en el modelado, y t-SNE como herramienta complementaria para la interpretación visual de los resultados.
#
# Por otra parte, el bajo porcentaje de varianza explicada en PCA de dos dimensiones sugiere que los datos presentan una estructura altamente multidimensional, lo que refuerza la necesidad de utilizar técnicas no lineales como t-SNE para su exploración visual.
#
# En definitiva, PCA permite una reducción eficiente para modelado, mientras que t-SNE ofrece una mejor visualización de patrones complejos, por lo que ambas técnicas se puedes utilizar de forma complementaria en el análisis.

# %% [markdown]
# Dado el alto costo computacional de t-SNE, se aplicó previamente una reducción de dimensionalidad mediante PCA, con el objetivo de reducir el ruido y mejorar la eficiencia del algoritmo. Además, se ajustó el parámetro perplexity a un valor intermedio (30), equilibrando la calidad de la visualización con el tiempo de ejecución.

# %%
# Paso 1: PCA
pca = PCA(n_components=14)
X_pca = pca.fit_transform(X_scaled)

# Paso 2: t-SNE
tsne = TSNE(
    n_components=2,
    perplexity=50,
    learning_rate=200,
    random_state=42
)

tsne_results_2 = tsne.fit_transform(X_pca)

# %%
# Crear DataFrame con resultados de t-SNE
tsne_df = pd.DataFrame(tsne_results_2, columns=["Dim1", "Dim2"])

# (Opcional) agregar variable de segmentación si la tienes
# tsne_df["Segment"] = df["Segment"]

# Estilo
sns.set(style="whitegrid")

plt.figure(figsize=(9,6))

sns.scatterplot(
    data=tsne_df,
    x="Dim1",
    y="Dim2",
    # hue="Segment",  # 👈 usa esto SOLO si tienes segmentación
    palette="Set2",
    alpha=0.7,
    edgecolor="black",
    s=60
)

plt.title("Visualización de Clientes con t-SNE (previo PCA)", fontsize=14, weight="bold")
plt.xlabel("Dimensión 1")
plt.ylabel("Dimensión 2")

plt.show()
# Out:
# C:\Users\cotec\AppData\Local\Temp\ipykernel_12140\3633031505.py:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %% [markdown]
# La aplicación de PCA previa a t-SNE no generó cambios significativos en la visualización, lo que sugiere que la estructura local de los datos ya estaba bien representada. Esto indica que la reducción de dimensionalidad no alteró sustancialmente las relaciones entre observaciones.

# %% [markdown]
# <b><font color= "red">Lección 4: Aplicación práctica de Clusterización con Python</b></font>
# <b> Objetivo: Implementar un pipeline de clusterización aplicando K-Means, DBSCAN y agrupamiento jerárquico. </b>

# %% [markdown]
# **Aplicar los tres algoritmos sobre el dataset preprocesado**

# %%
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

# %% [markdown]
# <font size=6>

# %%
X = X_scaled  # tus datos ya estandarizados

# %% [markdown]
# **Método del codo K-Means**

# %% [markdown]
# Se evaluaron valores de K en un rango de 2 a 15, ya que permite capturar posibles estructuras en los datos sin generar una segmentación excesivamente fragmentada y que dificulte la interpretación.

# %%
inertia = []

K_range = range(1, 16)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(K_range, inertia, marker='o')
plt.title("Método del Codo")
plt.xlabel("Número de clusters")
plt.ylabel("Inercia")
plt.show()

# %% [markdown]
# **Coeficiente de Silhouette**

# %%
for k in range(2, 16):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    print(f"K={k}, Silhouette Score={score:.3f}")
# Out:
# K=2, Silhouette Score=0.112
# K=3, Silhouette Score=0.106
# K=4, Silhouette Score=0.111
# K=5, Silhouette Score=0.152
# K=6, Silhouette Score=0.152
# K=7, Silhouette Score=0.161
# K=8, Silhouette Score=0.169
# K=9, Silhouette Score=0.177
# K=10, Silhouette Score=0.176
# K=11, Silhouette Score=0.184
# K=12, Silhouette Score=0.196
# K=13, Silhouette Score=0.206
# K=14, Silhouette Score=0.184
# K=15, Silhouette Score=0.212

# %% [markdown]
# Aunque el método del codo sugiere una reducción progresiva hasta valores cercanos a K=15, este número resulta poco práctico desde el punto de vista interpretativo. Además, el coeficiente de silueta no presenta mejoras significativas si comparamos los k, desde el k=9 al k=15. Por esta razón, se opta por un número de clusters más reducido, que permite un mejor equilibrio entre calidad del agrupamiento y utilidad analítica.
#
# Si bien el coeficiente de silueta continúa aumentando para valores mayores de K (Se hicieron pruebas con k mayores), este incremento es marginal y no justifica la complejidad adicional. Por ello, se considera más ópttima la elección de un valor intermedio que equilibra la calidad del agrupamiento y la interpretabilidad de los resultados.

# %% [markdown]
# **Coeficiente de Silhouette gráficamente**

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# 1) Usar tus datos reales
X = X_scaled

# 2) Probar distintos K
k_values = range(2, 16)
sil_scores = []

for k in k_values:
    kmeans = KMeans(
        n_clusters=k,
        init="k-means++",
        n_init=10,
        random_state=42
    )
    
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    sil_scores.append(score)

# 3) Graficar
plt.figure(figsize=(8, 5))
plt.plot(list(k_values), sil_scores, marker="o")
plt.title("Silhouette Score vs Número de Clusters")
plt.xlabel("Número de clusters (K)")
plt.ylabel("Silhouette promedio")
plt.xticks(list(k_values))
plt.grid(True, alpha=0.3)
plt.show()

# 4) Mejor K
best_k = list(k_values)[sil_scores.index(max(sil_scores))]
print(f"Mejor K según Silhouette: {best_k} (score={max(sil_scores):.3f})")
# Out:
# Mejor K según Silhouette: 15 (score=0.212)

# %% [markdown]
# Aunque el coeficiente de silueta continúa aumentando a medida que crece el número de clusters (se hicieron más pruebas con k mayores), los valores más altos se alcanzan con un número elevado de K, lo que dificulta la interpretabilidad del modelo. Por esta razón y las mencionadas con anterioridad, se selecciona un valor intermedio K=12, que representa un equilibrio entre calidad de agrupamiento y utilidad práctica, evitando el sobreajuste.

# %% [markdown]
# **K-Means final**

# %%
kmeans = KMeans(n_clusters=12, random_state=42, n_init=10)
kmeans_labels = kmeans.fit_predict(X)

# %% [markdown]
# **Visualización K-Means**

# %%
# Reducir a 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# DataFrame para graficar
df_plot = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
df_plot["Cluster"] = kmeans_labels

# Estilo
sns.set(style="whitegrid")

plt.figure(figsize=(9,6))

sns.scatterplot(
    data=df_plot,
    x="PC1",
    y="PC2",
    hue="Cluster",
    palette="Set2",
    alpha=0.7,
    edgecolor="black",
    s=60
)

plt.title("Clusters de Clientes con K-Means (K=12)", fontsize=14, weight="bold")
plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")

plt.show()

# %% [markdown]
# Del gráfico se puede observar que K-Means:
#
# Genera clusters relativamente equilibrados
#
# Se observa cierta estructura, pero con solapamiento
#
# Fuerza una segmentación incluso sin separación clara

# %% [markdown]
# **Clustering Jerárquico**

# %% [markdown]
# Se utilizó clustering jerárquico aglomerativo debido a su enfoque intuitivo de construcción progresiva de grupos. Para efectos comparativos, se empleó el mismo número de clusters determinado previamente mediante K-Means, permitiendo evaluar las diferencias entre métodos bajo condiciones similares.

# %%
hierarchical = AgglomerativeClustering(n_clusters=12)
hier_labels = hierarchical.fit_predict(X)

# %% [markdown]
# **Visualización Clustering Jerárquico**

# %%
# Reutilizamos el mismo PCA para comparar visualmente
df_plot["Cluster_H"] = hier_labels

plt.figure(figsize=(9,6))

sns.scatterplot(
    data=df_plot,
    x="PC1",
    y="PC2",
    hue="Cluster_H",
    palette="Set1",
    alpha=0.7,
    edgecolor="black",
    s=60
)

plt.title("Clusters de Clientes con Clustering Jerárquico (K=12)", fontsize=14, weight="bold")
plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")

plt.show()

# %% [markdown]
# La gráfica permite observar que el clustering jerárquico
#
# Presenta mayor dispersión que K-Means
#
# Clusteres menos homogéneos
#
# Más sensibilidad a ruido y estructura local ( se observa solapamiento alto, fragmentación en zonas pequeñas y ausencia de fronteras claras)

# %% [markdown]
# **DBSCAN**

# %% [markdown]
# "Tunning" epsilon

# %%
eps_values = np.linspace(0.5, 2.5, 10)  # puedes ajustar este rango
min_samples_values = [5, 10]

# %%
results = []

for eps in eps_values:
    for min_samples in min_samples_values:
        
        db = DBSCAN(eps=eps, min_samples=min_samples)
        labels = db.fit_predict(X)
        
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise = np.sum(labels == -1)
        
        sil = None
        mask = labels != -1
        
        if len(set(labels[mask])) >= 2:
            sil = silhouette_score(X[mask], labels[mask])
        
        results.append([eps, min_samples, n_clusters, n_noise, sil])

# %%
df_results = pd.DataFrame(
    results,
    columns=["eps", "min_samples", "n_clusters", "noise", "silhouette"]
)

df_results.sort_values(by="silhouette", ascending=False).head(20)
# Out:
#          eps  min_samples  n_clusters  noise  silhouette
# 1   0.500000           10          65   6615    0.572887
# 3   0.722222           10          68   5655    0.571999
# 2   0.722222            5         162   4670    0.530159
# 5   0.944444           10          88   4881    0.494321
# 0   0.500000            5         176   5723    0.490561
# 4   0.944444            5         184   3879    0.480717
# 7   1.166667           10          99   4532    0.470945
# 6   1.166667            5         219   3506    0.460935
# 9   1.388889           10         111   4223    0.452494
# 8   1.388889            5         241   3113    0.441583
# 11  1.611111           10         127   3864    0.434374
# 13  1.833333           10         136   3669    0.424264
# 10  1.611111            5         277   2703    0.421223
# 12  1.833333            5         286   2562    0.413476
# 15  2.055556           10          92   3177    0.282441
# ...

# %% [markdown]
# Aunque DBSCAN alcanza valores altos de coeficiente de silueta para ciertos parámetros, estos resultados se obtienen a costa de generar un gran número de clusters y una alta proporción de puntos clasificados como ruido. Esto indica que el dataset no presenta una estructura densa claramente definida, lo que limita la efectividad de este algoritmo para el problema analizado

# %% [markdown]
# Aunque DBSCAN alcanza valores altos de coeficiente de silueta para ciertos parámetros, estos resultados se obtienen a costa de generar un gran número de clusters y una alta proporción de puntos clasificados como ruido. Esto indica que el dataset no presenta una estructura densa claramente definida, lo que limita la efectividad de este algoritmo para el problema analizado

# %%
dbscan = DBSCAN(eps=2.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)

# %% [markdown]
# **Visualización**

# %%
# Reducir a 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

df_plot = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
df_plot["Cluster"] = dbscan_labels

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df_plot,
    x="PC1",
    y="PC2",
    hue="Cluster",
    palette="tab10",
    alpha=0.7
)

plt.title("Clusters con DBSCAN (modelo final)")
plt.show()

# %% [markdown]
# Los resultados obtenidos con DBSCAN muestran una alta fragmentación en los datos (muchos clusteres pequeños) y la presencia de múltiples clusters pequeños junto con puntos considerados ruido, lo que sugiere que el dataset no presenta una estructura de densidad claramente definida y no logra una estructura global clara.

# %% [markdown]
# **Visualización comparativa**

# %%
# Reducimos a 2D SOLO para visualizar
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# ---------------------------
# VISUALIZACIÓN COMPARATIVA
# ---------------------------

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# K-Means
axes[0].scatter(
    X_pca[:,0], X_pca[:,1],
    c=kmeans_labels,
    cmap="Set2",
    s=30,
    alpha=0.7
)
axes[0].set_title("K-Means (K=12)", weight="bold")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")

# DBSCAN
axes[1].scatter(
    X_pca[:,0], X_pca[:,1],
    c=dbscan_labels,
    cmap="tab10",
    s=30,
    alpha=0.7
)
axes[1].set_title("DBSCAN", weight="bold")
axes[1].set_xlabel("PC1")
axes[1].set_ylabel("PC2")

# Jerárquico
axes[2].scatter(
    X_pca[:,0], X_pca[:,1],
    c=hier_labels,
    cmap="Set1",
    s=30,
    alpha=0.7
)
axes[2].set_title("Clustering Jerárquico (K=12)", weight="bold")
axes[2].set_xlabel("PC1")
axes[2].set_ylabel("PC2")

plt.tight_layout()
plt.show()

# %% [markdown]
# La comparación de los métodos evidencia que no existe una segmentación natural bien definida en los datos. K-Means logra generar grupos más estructurados al imponer una partición fija, mientras que el clustering jerárquico presenta mayor solapamiento entre segmentos. Por su parte, DBSCAN revela una alta dispersión y fragmentación, indicando que los datos no presentan agrupaciones densas claras. En conjunto, los resultados sugieren una estructura compleja y poco separable

# %% [markdown]
# **Conclusiones**

# %% [markdown]
# - Los datos presentan alta complejidad y solapamiento
# - No existen clusters naturales bien definidos
# - La segmentación depende fuertemente del método utilizado
# - Las métricas (silhouette) confirman baja separación
# - DBSCAN valida la ausencia de densidad estructurada

# %% [markdown]
# Los resultados obtenidos sugieren que la segmentación de clientes no responde a una estructura intrínseca claramente diferenciada, sino a patrones difusos y superpuestos, lo que implica que cualquier estrategia de segmentación deberá interpretarse con cautela y validarse desde el negocio.
#
# Los resultados obtenidos sugieren que la segmentación de clientes no responde a una estructura intrínseca claramente diferenciada, sino a patrones difusos y superpuestos, lo que implica que cualquier estrategia de segmentación deberá interpretarse con cautela y validarse desde el negocio.
