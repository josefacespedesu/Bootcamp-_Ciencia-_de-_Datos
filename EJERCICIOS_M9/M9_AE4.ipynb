# %% [markdown]
# # **Live Coding 1**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as _sum, avg
import time

# %% [markdown]
# 1. Crear SparkSession

# %%
spark = SparkSession.builder \
    .appName("Demo Spark SQL") \
    .getOrCreate()

print("SparkSession creada correctamente")
print("Versión de Spark:", spark.version)
# Out:
# SparkSession creada correctamente
# Versión de Spark: 4.0.2

# %% [markdown]
# 2. Cargar datos desde CSV

# %%
ventas_df = spark.read.csv(
    "ventas.csv",
    header=True,
    inferSchema=True
)

print("\nSchema de ventas:")
ventas_df.printSchema()

print("\nPrimeras filas de ventas:")
ventas_df.show()
# Out:
# Schema de ventas:
# root
#  |-- id_venta: integer (nullable = true)
#  |-- id_sucursal: integer (nullable = true)
#  |-- producto: string (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- monto: integer (nullable = true)
#  |-- fecha: date (nullable = true)
#
#
# Primeras filas de ventas:
# +--------+-----------+----------+----------+------+----------+
# |id_venta|id_sucursal|  producto| categoria| monto|     fecha|
# +--------+-----------+----------+----------+------+----------+
# |       1|        784|   Mochila|Accesorios|438201|2025-05-04|
# |       2|        144|     Mouse|Tecnologia|266498|2025-09-23|
# |       3|        313|   Monitor|Tecnologia|426047|2025-10-27|
# |       4|        837|   Teclado|Tecnologia|523122|2025-11-02|
# |       5|        673| Impresora|   Oficina|845609|2025-02-11|
# |       6|        846|   Mochila|Accesorios|719403|2025-05-15|
# |       7|        635|   Monitor|Tecnologia|828197|2025-06-04|
# |       8|        823|Escritorio|   Oficina|915489|2025-05-17|
# |       9|        977|   Mochila|Accesorios|843867|2025-12-04|
# |      10|        728|   Mochila|Accesorios|612944|2025-06-15|
# |      11|        976|  Notebook|Tecnologia|256189|2025-11-18|
# |      12|        991|   Mochila|Accesorios|611953|2025-10-29|
# |      13|        765|Escritorio|   Oficina| 66938|2025-02-26|
# |      14|        992|   Monitor|Tecnologia| 16792|2025-09-05|
# |      15|        407|  Cuaderno|    Utiles|259807|2025-12-13|
# |      16|        787|  Notebook|Tecnologia|225540|2025-06-28|
# |      17|        248|   Teclado|Tecnologia|212675|2025-07-02|
# |      18|        293|     Lapiz|    Utiles| 73079|2025-12-24|
# |      19|       1055|     Silla|   Oficina|714948|2025-08-30|
# |      20|        604|  Notebook|Tecnologia|945617|2025-12-25|
# +--------+-----------+----------+----------+------+----------+
# only showing top 20 rows

# %% [markdown]
# 3. Cargar datos desde JSON

# %%
sucursales_df = spark.read.json("sucursales.json")

print("\nSchema de sucursales:")
sucursales_df.printSchema()

print("\nPrimeras filas de sucursales:")
sucursales_df.show()
# Out:
# Schema de sucursales:
# root
#  |-- id_sucursal: long (nullable = true)
#  |-- nombre_sucursal: string (nullable = true)
#  |-- region: string (nullable = true)
#
#
# Primeras filas de sucursales:
# +-----------+---------------+-------------+
# |id_sucursal|nombre_sucursal|       region|
# +-----------+---------------+-------------+
# |        101|   Sucursal 101|    Los Lagos|
# |        102|   Sucursal 102|   Valparaiso|
# |        103|   Sucursal 103|   Valparaiso|
# |        104|   Sucursal 104|    Los Lagos|
# |        105|   Sucursal 105|     Coquimbo|
# |        106|   Sucursal 106|   Valparaiso|
# |        107|   Sucursal 107|        Maule|
# |        108|   Sucursal 108|    Araucania|
# |        109|   Sucursal 109|  Antofagasta|
# |        110|   Sucursal 110|    Araucania|
# |        111|   Sucursal 111|    Araucania|
# |        112|   Sucursal 112|  Antofagasta|
# |        113|   Sucursal 113|Metropolitana|
# |        114|   Sucursal 114|    Araucania|
# |        115|   Sucursal 115|    Araucania|
# |        116|   Sucursal 116|   Valparaiso|
# |        117|   Sucursal 117|     Coquimbo|
# |        118|   Sucursal 118|  Antofagasta|
# |        119|   Sucursal 119|Metropolitana|
# |        120|   Sucursal 120|        Maule|
# +-----------+---------------+-------------+
# only showing top 20 rows

# %% [markdown]
# 4. Join entre DataFrames

# %%
df_join = ventas_df.join(sucursales_df, on="id_sucursal", how="inner")

print("\nDataFrame unido:")
df_join.show()
# Out:
# DataFrame unido:
# +-----------+--------+----------+----------+------+----------+---------------+-------------+
# |id_sucursal|id_venta|  producto| categoria| monto|     fecha|nombre_sucursal|       region|
# +-----------+--------+----------+----------+------+----------+---------------+-------------+
# |        784|       1|   Mochila|Accesorios|438201|2025-05-04|   Sucursal 784|    Los Lagos|
# |        144|       2|     Mouse|Tecnologia|266498|2025-09-23|   Sucursal 144|    Los Lagos|
# |        313|       3|   Monitor|Tecnologia|426047|2025-10-27|   Sucursal 313|    Araucania|
# |        837|       4|   Teclado|Tecnologia|523122|2025-11-02|   Sucursal 837|Metropolitana|
# |        673|       5| Impresora|   Oficina|845609|2025-02-11|   Sucursal 673|   Valparaiso|
# |        846|       6|   Mochila|Accesorios|719403|2025-05-15|   Sucursal 846|        Maule|
# |        635|       7|   Monitor|Tecnologia|828197|2025-06-04|   Sucursal 635|    Araucania|
# |        823|       8|Escritorio|   Oficina|915489|2025-05-17|   Sucursal 823|Metropolitana|
# |        977|       9|   Mochila|Accesorios|843867|2025-12-04|   Sucursal 977|       Biobio|
# |        728|      10|   Mochila|Accesorios|612944|2025-06-15|   Sucursal 728|     Coquimbo|
# |        976|      11|  Notebook|Tecnologia|256189|2025-11-18|   Sucursal 976|  Antofagasta|
# |        991|      12|   Mochila|Accesorios|611953|2025-10-29|   Sucursal 991|    Los Lagos|
# |        765|      13|Escritorio|   Oficina| 66938|2025-02-26|   Sucursal 765|    Araucania|
# |        992|      14|   Monitor|Tecnologia| 16792|2025-09-05|   Sucursal 992|    Araucania|
# |        407|      15|  Cuaderno|    Utiles|259807|2025-12-13|   Sucursal 407|   Valparaiso|
# |        787|      16|  Notebook|Tecnologia|225540|2025-06-28|   Sucursal 787|   Valparaiso|
# |        248|      17|   Teclado|Tecnologia|212675|2025-07-02|   Sucursal 248|       Biobio|
# |        293|      18|     Lapiz|    Utiles| 73079|2025-12-24|   Sucursal 293|Metropolitana|
# |       1055|      19|     Silla|   Oficina|714948|2025-08-30|  Sucursal 1055|       Biobio|
# |        604|      20|  Notebook|Tecnologia|945617|2025-12-25|   Sucursal 604|    Los Lagos|
# +-----------+--------+----------+----------+------+----------+---------------+-------------+
# only showing top 20 rows

# %% [markdown]
# 5. Registrar vista temporal

# %%
df_join.createOrReplaceTempView("ventas_sucursales")

# %% [markdown]
# 6. Consulta SQL con filtros y agregaciones

# %%
consulta = """
SELECT
    region,
    categoria,
    COUNT(*) AS cantidad_ventas,
    SUM(monto) AS total_ventas,
    ROUND(AVG(monto), 2) AS promedio_venta
FROM ventas_sucursales
WHERE monto > 10000
GROUP BY region, categoria
ORDER BY total_ventas DESC
"""

resultado_sql = spark.sql(consulta)

print("\nResultado de la consulta SQL:")
resultado_sql.show()
# Out:
# Resultado de la consulta SQL:
# +-------------+----------+---------------+------------+--------------+
# |       region| categoria|cantidad_ventas|total_ventas|promedio_venta|
# +-------------+----------+---------------+------------+--------------+
# |        Maule|Tecnologia|          57344| 27557990767|     480573.22|
# |    Araucania|Tecnologia|          53729| 25746748299|     479196.49|
# |    Los Lagos|Tecnologia|          52050| 24925091180|     478868.23|
# |  Antofagasta|Tecnologia|          48789| 23377169278|     479148.36|
# |     Coquimbo|Tecnologia|          46953| 22719304099|     483873.32|
# |Metropolitana|Tecnologia|          47170| 22608614781|     479300.72|
# |       Biobio|Tecnologia|          46716| 22388645824|     479250.06|
# |   Valparaiso|Tecnologia|          43980| 21091986853|     479581.33|
# |        Maule|   Oficina|          43175| 20761127233|     480859.92|
# |    Araucania|   Oficina|          40557| 19538177668|     481746.13|
# |    Los Lagos|   Oficina|          39198| 18861078947|     481174.52|
# |  Antofagasta|   Oficina|          36211| 17384612271|     480092.02|
# |Metropolitana|   Oficina|          35366| 17029906355|     481533.29|
# |       Biobio|   Oficina|          35045| 16864763669|     481231.66|
# |     Coquimbo|   Oficina|          34900| 16773367091|     480612.24|
# |   Valparaiso|   Oficina|          32869| 15743578890|     478979.55|
# |        Maule|    Utiles|          28425| 13675471640|     481107.18|
# |    Araucania|    Utiles|          26960| 12933614455|     479733.47|
# |    Los Lagos|    Utiles|          25905| 12430251263|     479839.85|
# |  Antofagasta|    Utiles|          24017| 11510281277|     479255.58|
# +-------------+----------+---------------+------------+--------------+
# only showing top 20 rows

# %% [markdown]
# 7. Ver plan de ejecución

# %%
print("\nPlan de ejecución:")
resultado_sql.explain(True)
# Out:
# Plan de ejecución:
# == Parsed Logical Plan ==
# 'Sort ['total_ventas DESC NULLS LAST], true
# +- 'Aggregate ['region, 'categoria], ['region, 'categoria, 'COUNT(1) AS cantidad_ventas#106, 'SUM('monto) AS total_ventas#107, 'ROUND('AVG('monto), 2) AS promedio_venta#108]
#    +- 'Filter ('monto > 10000)
#       +- 'UnresolvedRelation [ventas_sucursales], [], false
#
# == Analyzed Logical Plan ==
# region: string, categoria: string, cantidad_ventas: bigint, total_ventas: bigint, promedio_venta: double
# Sort [total_ventas#107L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#106L, sum(monto#21) AS total_ventas#107L, round(avg(monto#21), 2) AS promedio_venta#108]
#    +- Filter (monto#21 > 10000)
#       +- SubqueryAlias ventas_sucursales
#          +- View (`ventas_sucursales`, [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57])
#             +- Project [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57]
#                +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#                   :- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#                   +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Optimized Logical Plan ==
# Sort [total_ventas#107L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#106L, sum(monto#21) AS total_ventas#107L, round(avg(monto#21), 2) AS promedio_venta#108]
#    +- Project [categoria#20, monto#21, region#57]
#       +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#          :- Project [id_sucursal#18, categoria#20, monto#21]
#          :  +- Filter ((isnotnull(monto#21) AND (monto#21 > 10000)) AND isnotnull(id_sucursal#18))
#          :     +- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#          +- Project [id_sucursal#55L, region#57]
#             +- Filter isnotnull(id_sucursal#55L)
#                +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [total_ventas#107L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(total_ventas#107L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=321]
#       +- HashAggregate(keys=[region#57, categoria#20], functions=[count(1), sum(monto#21), avg(monto#21)], output=[region#57, categoria#20, cantidad_ventas#106L, total_ventas#107L, promedio_venta#108])
#          +- Exchange hashpartitioning(region#57, categoria#20, 200), ENSURE_REQUIREMENTS, [plan_id=318]
#             +- HashAggregate(keys=[region#57, categoria#20], functions=[partial_count(1), partial_sum(monto#21), partial_avg(monto#21)], output=[region#57, categoria#20, count#121L, sum#122L, sum#123, count#124L])
#                +- Project [categoria#20, monto#21, region#57]
#                   +- BroadcastHashJoin [cast(id_sucursal#18 as bigint)], [id_sucursal#55L], Inner, BuildRight, false
#                      :- Filter ((isnotnull(monto#21) AND (monto#21 > 10000)) AND isnotnull(id_sucursal#18))
#                      :  +- FileScan csv [id_sucursal#18,categoria#20,monto#21] Batched: false, DataFilters: [isnotnull(monto#21), (monto#21 > 10000), isnotnull(id_sucursal#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/ventas.csv], PartitionFilters: [], PushedFilters: [IsNotNull(monto), GreaterThan(monto,10000), IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:int,categoria:string,monto:int>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]),false), [plan_id=313]
#                         +- Filter isnotnull(id_sucursal#55L)
#                            +- FileScan json [id_sucursal#55L,region#57] Batched: false, DataFilters: [isnotnull(id_sucursal#55L)], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/content/sucursales.json], PartitionFilters: [], PushedFilters: [IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:bigint,region:string>

# %% [markdown]
# 8. Mini comparación de rendimiento

# %%
import time

consulta = """
SELECT
    region,
    categoria,
    COUNT(*) AS cantidad_ventas,
    SUM(monto) AS total_ventas,
    ROUND(AVG(monto), 2) AS promedio_venta
FROM ventas_grandes
WHERE monto > 100000
GROUP BY region, categoria
ORDER BY total_ventas DESC
"""

# Asegurar que la vista exista
df_join.createOrReplaceTempView("ventas_grandes")

# =========================
# 1. Escenario optimizado
# =========================
spark.conf.set("spark.sql.adaptive.enabled", "true")
spark.conf.set("spark.sql.codegen.wholeStage", "true")
spark.conf.set("spark.sql.cbo.enabled", "true")

inicio = time.time()
resultado_opt = spark.sql(consulta)
resultado_opt.show()
fin = time.time()

tiempo_opt = fin - inicio
print(f"Tiempo con optimizaciones activadas: {tiempo_opt:.4f} segundos")

print("\nPlan con optimizaciones activadas:")
resultado_opt.explain(True)

# =========================
# 2. Escenario menos optimizado
# =========================
spark.conf.set("spark.sql.adaptive.enabled", "false")
spark.conf.set("spark.sql.codegen.wholeStage", "false")
spark.conf.set("spark.sql.cbo.enabled", "false")

inicio = time.time()
resultado_no_opt = spark.sql(consulta)
resultado_no_opt.show()
fin = time.time()

tiempo_no_opt = fin - inicio
print(f"Tiempo con optimizaciones reducidas: {tiempo_no_opt:.4f} segundos")

print("\nPlan con optimizaciones reducidas:")
resultado_no_opt.explain(True)

# =========================
# 3. Comparación final
# =========================
print("\nComparación de tiempos:")
print(f"Con optimizaciones   : {tiempo_opt:.4f} s")
print(f"Sin optimizaciones   : {tiempo_no_opt:.4f} s")

if tiempo_no_opt > 0:
    mejora = ((tiempo_no_opt - tiempo_opt) / tiempo_no_opt) * 100
    print(f"Mejora estimada      : {mejora:.2f}%")
# Out:
# +-------------+----------+---------------+------------+--------------+
# |       region| categoria|cantidad_ventas|total_ventas|promedio_venta|
# +-------------+----------+---------------+------------+--------------+
# |        Maule|Tecnologia|          51832| 27257087382|     525873.73|
# |    Araucania|Tecnologia|          48518| 25459278444|     524738.83|
# |    Los Lagos|Tecnologia|          47058| 24647579467|     523770.23|
# |  Antofagasta|Tecnologia|          44057| 23118664854|     524744.42|
# |     Coquimbo|Tecnologia|          42471| 22470951588|      529089.3|
# |Metropolitana|Tecnologia|          42610| 22355044971|     524643.16|
# |       Biobio|Tecnologia|          42234| 22142225135|     524274.88|
# |   Valparaiso|Tecnologia|          39711| 20857602791|     525234.89|
# |        Maule|   Oficina|          39038| 20530259695|      525904.5|
# |    Araucania|   Oficina|          36734| 19326737329|     526126.68|
# |    Los Lagos|   Oficina|          35526| 18659428756|     525233.03|
# |  Antofagasta|   Oficina|          32759| 17192985359|     524832.42|
# |Metropolitana|   Oficina|          31939| 16842235832|     527325.08|
# |       Biobio|   Oficina|          31658| 16680328360|     526891.41|
# |     Coquimbo|   Oficina|          31554| 16590415134|     525778.51|
# |   Valparaiso|   Oficina|          29690| 15568713435|     524375.66|
# |        Maule|    Utiles|          25711| 13527592672|     526140.28|
# |    Araucania|    Utiles|          24337| 12787777461|     525445.92|
# |    Los Lagos|    Utiles|          23436| 12294316582|     524591.08|
# |  Antofagasta|    Utiles|          21675| 11383014734|     525167.92|
# +-------------+----------+---------------+------------+--------------+
# only showing top 20 rows
# Tiempo con optimizaciones activadas: 4.0672 segundos
#
# Plan con optimizaciones activadas:
# == Parsed Logical Plan ==
# 'Sort ['total_ventas DESC NULLS LAST], true
# +- 'Aggregate ['region, 'categoria], ['region, 'categoria, 'COUNT(1) AS cantidad_ventas#490, 'SUM('monto) AS total_ventas#491, 'ROUND('AVG('monto), 2) AS promedio_venta#492]
#    +- 'Filter ('monto > 100000)
#       +- 'UnresolvedRelation [ventas_grandes], [], false
#
# == Analyzed Logical Plan ==
# region: string, categoria: string, cantidad_ventas: bigint, total_ventas: bigint, promedio_venta: double
# Sort [total_ventas#491L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#490L, sum(monto#21) AS total_ventas#491L, round(avg(monto#21), 2) AS promedio_venta#492]
#    +- Filter (monto#21 > 100000)
#       +- SubqueryAlias ventas_grandes
#          +- View (`ventas_grandes`, [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57])
#             +- Project [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57]
#                +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#                   :- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#                   +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Optimized Logical Plan ==
# Sort [total_ventas#491L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#490L, sum(monto#21) AS total_ventas#491L, round(avg(monto#21), 2) AS promedio_venta#492]
#    +- Project [categoria#20, monto#21, region#57]
#       +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#          :- Project [id_sucursal#18, categoria#20, monto#21]
#          :  +- Filter ((isnotnull(monto#21) AND (monto#21 > 100000)) AND isnotnull(id_sucursal#18))
#          :     +- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#          +- Project [id_sucursal#55L, region#57]
#             +- Filter isnotnull(id_sucursal#55L)
#                +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [total_ventas#491L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(total_ventas#491L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=2412]
#       +- HashAggregate(keys=[region#57, categoria#20], functions=[count(1), sum(monto#21), avg(monto#21)], output=[region#57, categoria#20, cantidad_ventas#490L, total_ventas#491L, promedio_venta#492])
#          +- Exchange hashpartitioning(region#57, categoria#20, 200), ENSURE_REQUIREMENTS, [plan_id=2409]
#             +- HashAggregate(keys=[region#57, categoria#20], functions=[partial_count(1), partial_sum(monto#21), partial_avg(monto#21)], output=[region#57, categoria#20, count#505L, sum#506L, sum#507, count#508L])
#                +- Project [categoria#20, monto#21, region#57]
#                   +- BroadcastHashJoin [cast(id_sucursal#18 as bigint)], [id_sucursal#55L], Inner, BuildRight, false
#                      :- Filter ((isnotnull(monto#21) AND (monto#21 > 100000)) AND isnotnull(id_sucursal#18))
#                      :  +- FileScan csv [id_sucursal#18,categoria#20,monto#21] Batched: false, DataFilters: [isnotnull(monto#21), (monto#21 > 100000), isnotnull(id_sucursal#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/ventas.csv], PartitionFilters: [], PushedFilters: [IsNotNull(monto), GreaterThan(monto,100000), IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:int,categoria:string,monto:int>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]),false), [plan_id=2404]
#                         +- Filter isnotnull(id_sucursal#55L)
#                            +- FileScan json [id_sucursal#55L,region#57] Batched: false, DataFilters: [isnotnull(id_sucursal#55L)], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/content/sucursales.json], PartitionFilters: [], PushedFilters: [IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:bigint,region:string>
#
# +-------------+----------+---------------+------------+--------------+
# |       region| categoria|cantidad_ventas|total_ventas|promedio_venta|
# +-------------+----------+---------------+------------+--------------+
# |        Maule|Tecnologia|          51832| 27257087382|     525873.73|
# |    Araucania|Tecnologia|          48518| 25459278444|     524738.83|
# |    Los Lagos|Tecnologia|          47058| 24647579467|     523770.23|
# |  Antofagasta|Tecnologia|          44057| 23118664854|     524744.42|
# |     Coquimbo|Tecnologia|          42471| 22470951588|      529089.3|
# |Metropolitana|Tecnologia|          42610| 22355044971|     524643.16|
# |       Biobio|Tecnologia|          42234| 22142225135|     524274.88|
# |   Valparaiso|Tecnologia|          39711| 20857602791|     525234.89|
# |        Maule|   Oficina|          39038| 20530259695|      525904.5|
# |    Araucania|   Oficina|          36734| 19326737329|     526126.68|
# |    Los Lagos|   Oficina|          35526| 18659428756|     525233.03|
# |  Antofagasta|   Oficina|          32759| 17192985359|     524832.42|
# |Metropolitana|   Oficina|          31939| 16842235832|     527325.08|
# |       Biobio|   Oficina|          31658| 16680328360|     526891.41|
# |     Coquimbo|   Oficina|          31554| 16590415134|     525778.51|
# |   Valparaiso|   Oficina|          29690| 15568713435|     524375.66|
# |        Maule|    Utiles|          25711| 13527592672|     526140.28|
# |    Araucania|    Utiles|          24337| 12787777461|     525445.92|
# |    Los Lagos|    Utiles|          23436| 12294316582|     524591.08|
# |  Antofagasta|    Utiles|          21675| 11383014734|     525167.92|
# +-------------+----------+---------------+------------+--------------+
# only showing top 20 rows
# Tiempo con optimizaciones reducidas: 5.7890 segundos
#
# Plan con optimizaciones reducidas:
# == Parsed Logical Plan ==
# 'Sort ['total_ventas DESC NULLS LAST], true
# +- 'Aggregate ['region, 'categoria], ['region, 'categoria, 'COUNT(1) AS cantidad_ventas#534, 'SUM('monto) AS total_ventas#535, 'ROUND('AVG('monto), 2) AS promedio_venta#536]
#    +- 'Filter ('monto > 100000)
#       +- 'UnresolvedRelation [ventas_grandes], [], false
#
# == Analyzed Logical Plan ==
# region: string, categoria: string, cantidad_ventas: bigint, total_ventas: bigint, promedio_venta: double
# Sort [total_ventas#535L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#534L, sum(monto#21) AS total_ventas#535L, round(avg(monto#21), 2) AS promedio_venta#536]
#    +- Filter (monto#21 > 100000)
#       +- SubqueryAlias ventas_grandes
#          +- View (`ventas_grandes`, [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57])
#             +- Project [id_sucursal#18, id_venta#17, producto#19, categoria#20, monto#21, fecha#22, nombre_sucursal#56, region#57]
#                +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#                   :- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#                   +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Optimized Logical Plan ==
# Sort [total_ventas#535L DESC NULLS LAST], true
# +- Aggregate [region#57, categoria#20], [region#57, categoria#20, count(1) AS cantidad_ventas#534L, sum(monto#21) AS total_ventas#535L, round(avg(monto#21), 2) AS promedio_venta#536]
#    +- Project [categoria#20, monto#21, region#57]
#       +- Join Inner, (cast(id_sucursal#18 as bigint) = id_sucursal#55L)
#          :- Project [id_sucursal#18, categoria#20, monto#21]
#          :  +- Filter ((isnotnull(monto#21) AND (monto#21 > 100000)) AND isnotnull(id_sucursal#18))
#          :     +- Relation [id_venta#17,id_sucursal#18,producto#19,categoria#20,monto#21,fecha#22] csv
#          +- Project [id_sucursal#55L, region#57]
#             +- Filter isnotnull(id_sucursal#55L)
#                +- Relation [id_sucursal#55L,nombre_sucursal#56,region#57] json
#
# == Physical Plan ==
# Sort [total_ventas#535L DESC NULLS LAST], true, 0
# +- Exchange rangepartitioning(total_ventas#535L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=2522]
#    +- HashAggregate(keys=[region#57, categoria#20], functions=[count(1), sum(monto#21), avg(monto#21)], output=[region#57, categoria#20, cantidad_ventas#534L, total_ventas#535L, promedio_venta#536])
#       +- Exchange hashpartitioning(region#57, categoria#20, 200), ENSURE_REQUIREMENTS, [plan_id=2519]
#          +- HashAggregate(keys=[region#57, categoria#20], functions=[partial_count(1), partial_sum(monto#21), partial_avg(monto#21)], output=[region#57, categoria#20, count#549L, sum#550L, sum#551, count#552L])
#             +- Project [categoria#20, monto#21, region#57]
#                +- BroadcastHashJoin [cast(id_sucursal#18 as bigint)], [id_sucursal#55L], Inner, BuildRight, false
#                   :- Filter ((isnotnull(monto#21) AND (monto#21 > 100000)) AND isnotnull(id_sucursal#18))
#                   :  +- FileScan csv [id_sucursal#18,categoria#20,monto#21] Batched: false, DataFilters: [isnotnull(monto#21), (monto#21 > 100000), isnotnull(id_sucursal#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/ventas.csv], PartitionFilters: [], PushedFilters: [IsNotNull(monto), GreaterThan(monto,100000), IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:int,categoria:string,monto:int>
#                   +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]),false), [plan_id=2514]
#                      +- Filter isnotnull(id_sucursal#55L)
#                         +- FileScan json [id_sucursal#55L,region#57] Batched: false, DataFilters: [isnotnull(id_sucursal#55L)], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/content/sucursales.json], PartitionFilters: [], PushedFilters: [IsNotNull(id_sucursal)], ReadSchema: struct<id_sucursal:bigint,region:string>
#
#
# Comparación de tiempos:
# Con optimizaciones   : 4.0672 s
# Sin optimizaciones   : 5.7890 s
# Mejora estimada      : 29.74%

# %% [markdown]
# 9. Cerrar sesión

# %%
spark.stop()
print("\nSparkSession finalizada")
# Out:
# SparkSession finalizada

# %% [markdown]
# # **Live Coding 2**
